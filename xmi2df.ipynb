# %%
from xmi2df import process_xmi_files

# %%
# Process all XMI files and concatenate the results
data_path = 'habernal.gurevych.2017.argumentation.mining.CL.data/data/gold.data.toulmin/'
type_system_file = 'TypeSystem.xml'

df = process_xmi_files(data_path, type_system_file)

# %%
df.head()
# Out:
# type     de.tudarmstadt.ukp.dkpro.argumentation.types.Backing  \
# file
# 1021.xmi  [It was boring, tedious, slow and frustrating....
# 1037.xmi                                                NaN
# 1045.xmi  [And if the answer to that is "Maybe, but thos...
# 1064.xmi  [My 8yr-old is already enjoying our sessions w...
# 1084.xmi                                                NaN
#
# type     de.tudarmstadt.ukp.dkpro.argumentation.types.Claim  \
# file
# 1021.xmi  [But don't assume that one size fits everybody...
# 1037.xmi                                                 []
# 1045.xmi  [Education at home is nothing like education a...
# 1064.xmi                                                 []
# 1084.xmi                  [School can be very bad for you.]
#
# type     de.tudarmstadt.ukp.dkpro.argumentation.types.Premise  \
# file
# 1021.xmi  [It was boring, tedious, slow and frustrating....
# 1037.xmi  [Lesson plans (and the national curriculum) ar...
# ...
